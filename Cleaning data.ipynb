# %%
import pandas as pd

# %%
import pandas as pd

location='https://github.com/Samikpan/PUBPOL542/raw/main/'
Financial_data=location+'Financial_Development_FD.xlsx'
Financial_index = pd.read_excel(Financial_data,'Financial Development (FD)')

# %%
Financial_indexTest=Financial_index.copy()

# %%
Financial_indexTest.describe()
# Out:
#        Financial Development Index  Unnamed: 2  \
# count                   180.000000         0.0
# mean                      0.324801         NaN
# std                       0.225319         NaN
# min                       0.046520         NaN
# 25%                       0.143710         NaN
# 50%                       0.250494         NaN
# 75%                       0.442935         NaN
# max                       0.963959         NaN
#
#        Financial Institutions Access Index  Unnamed: 4  \
# count                           180.000000         0.0
# mean                              0.374124         NaN
# std                               0.273026         NaN
# min                               0.000000         NaN
# 25%                               0.118856         NaN
# 50%                               0.356603         NaN
# 75%                               0.569485         NaN
# max                               1.000000         NaN
#
# ...

# %%
Financial_indexTest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 19 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unnamed: 0                               180 non-null    object
#  1   Financial Development Index              180 non-null    float64
#  2   Unnamed: 2                               0 non-null      float64
#  3   Financial Institutions Access Index      180 non-null    float64
#  4   Unnamed: 4                               0 non-null      float64
#  5   Financial Institutions Depth Index       180 non-null    float64
#  6   Unnamed: 6                               0 non-null      float64
#  7   Financial Institutions Efficiency Index  180 non-null    float64
#  8   Unnamed: 8                               0 non-null      float64
#  9   Financial Institutions Index             180 non-null    float64
# ...

# %%
Financial_indexTest[:]
# Out:
#                               Unnamed: 0  Financial Development Index  \
# 0                                Albania                     0.199178
# 1                                Algeria                     0.144825
# 2                                 Angola                     0.156810
# 3                    Antigua and Barbuda                     0.314413
# 4                              Argentina                     0.321531
# ..                                   ...                          ...
# 175                              Vanuatu                     0.196999
# 176  Venezuela, Republica Bolivariana de                     0.234540
# 177                              Vietnam                     0.386524
# 178                   Yemen, Republic of                     0.121234
# 179                               Zambia                     0.117064
#
#      Unnamed: 2  Financial Institutions Access Index  Unnamed: 4  \
# ...

# %%
cols = [2,4,6,8,10,12,14,16,18]
Financial_indexTest.drop(Financial_index.columns[cols],axis=1,inplace=True)

# %%
Financial_indexTest[:]
# Out:
#                               Unnamed: 0  Financial Development Index  \
# 0                                Albania                     0.199178
# 1                                Algeria                     0.144825
# 2                                 Angola                     0.156810
# 3                    Antigua and Barbuda                     0.314413
# 4                              Argentina                     0.321531
# ..                                   ...                          ...
# 175                              Vanuatu                     0.196999
# 176  Venezuela, Republica Bolivariana de                     0.234540
# 177                              Vietnam                     0.386524
# 178                   Yemen, Republic of                     0.121234
# 179                               Zambia                     0.117064
#
#      Financial Institutions Access Index  Financial Institutions Depth Index  \
# ...

# %%
Financial_indexTest.rename(columns={'Unnamed: 0':'Country'}, inplace = True) ### renaming an unnamed column

# %%
Financial_indexTest[:]
# Out:
#                                  Country  Financial Development Index  \
# 0                                Albania                     0.199178
# 1                                Algeria                     0.144825
# 2                                 Angola                     0.156810
# 3                    Antigua and Barbuda                     0.314413
# 4                              Argentina                     0.321531
# ..                                   ...                          ...
# 175                              Vanuatu                     0.196999
# 176  Venezuela, Republica Bolivariana de                     0.234540
# 177                              Vietnam                     0.386524
# 178                   Yemen, Republic of                     0.121234
# 179                               Zambia                     0.117064
#
#      Financial Institutions Access Index  Financial Institutions Depth Index  \
# ...

# %%
Financial_indexTest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 10 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Country                                  180 non-null    object
#  1   Financial Development Index              180 non-null    float64
#  2   Financial Institutions Access Index      180 non-null    float64
#  3   Financial Institutions Depth Index       180 non-null    float64
#  4   Financial Institutions Efficiency Index  180 non-null    float64
#  5   Financial Institutions Index             180 non-null    float64
#  6   Financial Markets Access Index           180 non-null    float64
#  7   Financial Markets Depth Index            180 non-null    float64
#  8   Financial Markets Efficiency Index       180 non-null    float64
#  9   Financial Markets Index                  180 non-null    float64
# ...

# %%
Financial_FinalData = Financial_indexTest.iloc[:, [0,1,4]]

# %%
Financial_FinalData
# Out:
#                                  Country  Financial Development Index  \
# 0                                Albania                     0.199178
# 1                                Algeria                     0.144825
# 2                                 Angola                     0.156810
# 3                    Antigua and Barbuda                     0.314413
# 4                              Argentina                     0.321531
# ..                                   ...                          ...
# 175                              Vanuatu                     0.196999
# 176  Venezuela, Republica Bolivariana de                     0.234540
# 177                              Vietnam                     0.386524
# 178                   Yemen, Republic of                     0.121234
# 179                               Zambia                     0.117064
#
#      Financial Institutions Efficiency Index
# 0                                   0.606880
# ...
